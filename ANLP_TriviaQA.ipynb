# %%
# !pip install -q transformers accelerate bitsandbytes lexicalrichness
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.8/97.8 kB 4.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for lexicalrichness (setup.py) ... done

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer
from datasets import load_dataset
from sentence_transformers import SentenceTransformer
from sklearn.cluster import DBSCAN
from lexicalrichness import LexicalRichness
import numpy as np
import pandas as pd
from collections import Counter

# %%
model_name = "microsoft/phi-2"
tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True)
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    torch_dtype=torch.float16,
    device_map="auto",
    trust_remote_code=True
)
tokenizer.pad_token = tokenizer.eos_token
# Out:
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# added_tokens.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/99.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/735 [00:00<?, ?B/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/564M [00:00<?, ?B/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]

# %%
model_name = "Qwen/Qwen2.5-3B-Instruct"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    torch_dtype=torch.float16,
    device_map="auto"
)
tokenizer.pad_token = tokenizer.eos_token
# Out:
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# config.json:   0%|          | 0.00/661 [00:00<?, ?B/s]
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/2.20G [00:00<?, ?B/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/3.97G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/242 [00:00<?, ?B/s]

# %%
dataset = load_dataset("trivia_qa", "unfiltered.nocontext", split="validation[:100]")
questions = [item['question'] for item in dataset]
answers = [item['answer']['value'] for item in dataset]
# Out:
# Resolving data files:   0%|          | 0/26 [00:00<?, ?it/s]

# %%
def generate_responses(question, num_samples=5):
    responses = []
    for _ in range(num_samples):
        prompt = f"Answer this question briefly: {question}\nAnswer:"
        inputs = tokenizer(prompt, return_tensors="pt").to(model.device)

        outputs = model.generate(
            **inputs,
            max_new_tokens=50,
            do_sample=True,
            temperature=0.7,
            top_p=0.9,
            pad_token_id=tokenizer.eos_token_id
        )

        response = tokenizer.decode(outputs[0], skip_special_tokens=True)
        response = response.split("Answer:")[-1].strip()
        responses.append(response)

    return responses

# %%
all_responses = []
for i, q in enumerate(questions):
    print(f"Processing {i+1}/100: {q[:50]}...")
    responses = generate_responses(q)
    all_responses.append(responses)
# Out:
# Processing 1/100: Who was the man behind The Chipmunks?...
# Processing 2/100: What star sign is Jamie Lee Curtis?...
# Processing 3/100: Which Lloyd Webber musical premiered in the US on ...
# Processing 4/100: Who was the next British Prime Minister after Arth...
# Processing 5/100: Who had a 70s No 1 hit with Kiss You All Over?...
# Processing 6/100: What claimed the life of singer Kathleen Ferrier?...
# Processing 7/100: Rita Coolidge sang the title song for which Bond f...
# Processing 8/100: To the nearest million what is the population of A...
# Processing 9/100: What was the last US state to reintroduce alcohol ...
# Processing 10/100: Which actress was voted Miss Greenwich Village in ...
# Processing 11/100: What is the Japanese share index called?...
# Processing 12/100: What was the name of Michael Jackson's autobiograp...
# Processing 13/100: In which decade did stereo records first go on sal...
# Processing 14/100: What was golfing great Ben Hogan's famous reply wh...
# Processing 15/100: In what year's Olympics were electric timing devic...
# Processing 16/100: Why is the site of a boxing match called a ring wh...
# Processing 17/100: In the very first Boston Marathon, 15 runners comp...
# Processing 18/100: "How many different animal shapes are there in the...
# Processing 19/100: Which volcano in Tanzania is the highest mountain ...
# Processing 20/100: The flag of Libya is a plain rectangle of which co...
# Processing 21/100: Of which African country is Niamey the capital?...
# Processing 22/100: Who was the director of the CIA from 1976-81?...
# Processing 23/100: Which musical featured the song The Street Where Y...
# Processing 24/100: "Who was the target of the failed ""Bomb Plot"" of...
# Processing 25/100: Who had an 80s No 1 hit with Hold On To The Nights...
# Processing 26/100: Who directed the classic 30s western Stagecoach?...
# Processing 27/100: Dave Gilmore and Roger Waters were in which rock g...
# Processing 28/100: Which highway was Revisited in a classic 60s album...
# Processing 29/100: Which was the only eastern bloc country to partici...
# Processing 30/100: Which 90s sci fi series with James Belushi was bas...
# Processing 31/100: If I Were A Rich Man Was a big hit from which stag...
# Processing 32/100: Men Against the Sea and Pitcairn's Island were two...
# Processing 33/100: What is the only novel to top the best-seller list...
# Processing 34/100: To whom did Helen Keller dedicate her autobiograph...
# Processing 35/100: "Complete this Biblical quotation: ""It is easier ...
# Processing 36/100: What was Truman Capote's last name before he was a...
# Processing 37/100: What book knocked Henry Kissinger's White house Ye...
# Processing 38/100: In Lewis Carroll's poem The Hunting of the Snark, ...
# Processing 39/100: In what state was playwright Tennessee Williams bo...
# Processing 40/100: Who was the only Englishman to become Pope?...
# Processing 41/100: In the Bible, who did the sun and moon stand still...
# Processing 42/100: What Michelle Pfeiffer movie got a boost from the ...
# Processing 43/100: In the Bible, who saw the handwriting on the wall?...
# Processing 44/100: What comic strip character was named after heavywe...
# Processing 45/100: What was President Gerald Ford's middle name?...
# Processing 46/100: Who recorded the When Harry Met Sally soundtrack?...
# Processing 47/100: Art Garfunkel trained for which profession althoug...
# Processing 48/100: Who was the last inmate of Spandau jail in Berlin?...
# Processing 49/100: What was Eddie Murphy's first movie?...
# Processing 50/100: In the 80s who wrote the novel Empire of The Sun?...
# Processing 51/100: Kagoshima international airport is in which countr...
# Processing 52/100: In which sport could the Pacers take on the Piston...
# Processing 53/100: Kim Carnes' nine weeks at No 1 with Bette Davis Ey...
# Processing 54/100: Where in Canada is the Lion's Gate bridge?...
# Processing 55/100: What was Walter Matthau's first movie?...
# Processing 56/100: Otis Barton was a pioneer in exploring where?...
# Processing 57/100: Where in England was actor Nigel Hawthorne born?...
# Processing 58/100: What would Kevin Scale have been called if it had ...
# Processing 59/100: What mythological beast has the head of a man, the...
# Processing 60/100: In Greek mythology, who were Arges, Brontes and St...
# Processing 61/100: In Greek mythology, what were the names of Oedipus...
# Processing 62/100: Which musician founded the Red Hot Peppers?...
# Processing 63/100: Where did the Shinning Path terrorists operate?...
# Processing 64/100: How old was Jimi Hendrix when he died?...
# Processing 65/100: Which Brit broke the land speed record in 1990 in ...
# Processing 66/100: In which state was Gene Vincent born?...
# Processing 67/100: How was the European Recovery Program in the 1940s...
# Processing 68/100: Brandon Lee died during the making of which movie?...
# Processing 69/100: Who had a 70s No 1 hit with Let's Do It Again?...
# Processing 70/100: Who had a Too Legit To Quit Tour?...
# Processing 71/100: "According to Rudyard Kipling what were the ""two ...
# Processing 72/100: Who is the most successful UK solo artist in the U...
# Processing 73/100: Where was horse racing's Breeder's Cup held in 198...
# Processing 74/100: Which country does the airline TAAG come from?...
# Processing 75/100: Which US No 1 single came from Diana Ross's platin...
# Processing 76/100: River Phoenix died during the making of which movi...
# Processing 77/100: Which artist David was born in Bradford UK?...
# Processing 78/100: What is Mel Gibson's middle name?...
# Processing 79/100: Richard Daley was mayor of which city for 21 years...
# Processing 80/100: "In which movie did Garbo say, ""I want to be alon...
# Processing 81/100: Robert Kirkpatrick of California grew the world's ...
# Processing 82/100: What is Osbert Lancaster best known for producing?...
# Processing 83/100: Who was the defending champion when Martina Navrat...
# Processing 84/100: Who was the first US-born winner of golf's British...
# Processing 85/100: In which country is the Sky Train Rail bridge?...
# Processing 86/100: What was the Paramount Film Company originally cal...
# Processing 87/100: Which founder of the company Triad was accused by ...
# Processing 88/100: Who was the first person after Scott to reach the ...
# Processing 89/100: Which journalist first told the world about the My...
# Processing 90/100: What is the name of Terence and Shirley Conran's d...
# Processing 91/100: Which drink did The Spice Girls promote?...
# Processing 92/100: Who was the youngest brother in the Beach Boys?...
# Processing 93/100: Which actress was called by the US Senate a 'power...
# Processing 94/100: Who first hosted Family Feud?...
# Processing 95/100: What did the Lone Ranger's title Kemo Sabe mean in...
# Processing 96/100: Who or what was Gentle Ben in the 60s TV series?...
# Processing 97/100: Which 70s show was based on the British show Till ...
# Processing 98/100: On what date in 1969 did Neil Armstrong first set ...
# Processing 99/100: Bandar Seri Begawan International airport is in wh...
# Processing 100/100: What was the profession of Paul Strand (1890 - 197...

# %%
embedding_model = SentenceTransformer('all-MiniLM-L6-v2')

def semantic_entropy(responses):
    if len(responses) < 2:
        return 0.0

    embeddings = embedding_model.encode(responses)
    clustering = DBSCAN(eps=0.5, min_samples=1, metric='cosine').fit(embeddings)
    labels = clustering.labels_

    cluster_counts = Counter(labels)
    total = len(labels)
    probs = [count / total for count in cluster_counts.values()]

    entropy = -sum(p * np.log(p) for p in probs if p > 0)
    return entropy

def self_consistency(responses):
    if len(responses) < 2:
        return 1.0

    normalized = [r.strip().lower()[:50] for r in responses]
    most_common = Counter(normalized).most_common(1)[0][1]
    consistency = most_common / len(responses)

    return 1 - consistency

def token_entropy_approx(responses):
    all_tokens = []
    for response in responses:
        tokens = response.lower().split()
        all_tokens.extend(tokens)

    if len(all_tokens) == 0:
        return 0.0

    token_counts = Counter(all_tokens)
    total = len(all_tokens)
    probs = [count / total for count in token_counts.values()]

    entropy = -sum(p * np.log(p) for p in probs if p > 0)
    return entropy

def perplexity_approx(responses):
    token_ent = token_entropy_approx(responses)
    return np.exp(token_ent)

def lexical_diversity(responses):
    combined_text = " ".join(responses)

    if len(combined_text.strip()) == 0:
        return 0.0

    lex = LexicalRichness(combined_text)
    try:
        ttr = lex.ttr
    except:
        ttr = 0.0

    return ttr

# %%
results = []

for i, responses in enumerate(all_responses):
    se = semantic_entropy(responses)
    sc = self_consistency(responses)
    te = token_entropy_approx(responses)
    ppl = perplexity_approx(responses)
    ld = lexical_diversity(responses)

    results.append({
        'question': questions[i],
        'semantic_entropy': se,
        'self_consistency': sc,
        'token_entropy': te,
        'perplexity': ppl,
        'lexical_diversity': ld
    })

df = pd.DataFrame(results)

# %%
def check_correctness(response, ground_truth):
    response_lower = response.strip().lower()
    truth_lower = ground_truth.strip().lower()

    if truth_lower in response_lower:
        return True

    response_words = set(response_lower.split())
    truth_words = set(truth_lower.split())
    overlap = len(response_words & truth_words) / max(len(truth_words), 1)

    return overlap > 0.5

correctness = []
for i, responses in enumerate(all_responses):
    correct = any(check_correctness(r, answers[i]) for r in responses)
    correctness.append(correct)

df['correct'] = correctness
print(f"Accuracy: {sum(correctness)/len(correctness):.2%}")
# Out:
# Accuracy: 35.00%

# %%
def calculate_ece(predictions, correctness, n_bins=10):
    df_temp = pd.DataFrame({
        'pred': predictions,
        'correct': correctness
    })

    df_temp['bin'] = pd.cut(df_temp['pred'], bins=n_bins, labels=False, duplicates='drop')

    ece = 0.0
    for bin_idx in df_temp['bin'].unique():
        if pd.isna(bin_idx):
            continue

        bin_data = df_temp[df_temp['bin'] == bin_idx]

        if len(bin_data) == 0:
            continue

        avg_confidence = bin_data['pred'].mean()
        avg_accuracy = bin_data['correct'].mean()
        bin_weight = len(bin_data) / len(df_temp)

        ece += bin_weight * abs(avg_confidence - avg_accuracy)

    return ece

metric_names = ['semantic_entropy', 'self_consistency', 'token_entropy', 'perplexity', 'lexical_diversity']

print("\nTriviaQA (Factual Category) ECE Results:")
for metric in metric_names:
    normalized = (df[metric] - df[metric].min()) / (df[metric].max() - df[metric].min() + 1e-8)
    ece = calculate_ece(normalized, df['correct'])
    print(f"{metric}: ECE = {ece:.4f}")
# Out:
# TriviaQA (Factual Category) ECE Results:
# semantic_entropy: ECE = 0.3727
# self_consistency: ECE = 0.4250
# token_entropy: ECE = 0.3804
# perplexity: ECE = 0.2076
# lexical_diversity: ECE = 0.2091

# %%
df.to_csv('triviaqa_results.csv', index=False)
