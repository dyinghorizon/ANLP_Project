# %%
# !pip install -q transformers accelerate bitsandbytes lexicalrichness sentence-transformers datasets scikit-learn
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.8/97.8 kB 10.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.4/59.4 MB 14.2 MB/s eta 0:00:00
#   Building wheel for lexicalrichness (setup.py) ... done

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer
from datasets import load_dataset
from sentence_transformers import SentenceTransformer
from sklearn.cluster import DBSCAN
from lexicalrichness import LexicalRichness
import numpy as np
import pandas as pd
from collections import Counter

# %%
model_name = "Qwen/Qwen2.5-3B-Instruct"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    torch_dtype=torch.float16,
    device_map="auto"
)
tokenizer.pad_token = tokenizer.eos_token
# Out:
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# config.json:   0%|          | 0.00/661 [00:00<?, ?B/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/3.97G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/2.20G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/242 [00:00<?, ?B/s]

# %%
dataset = load_dataset("commonsense_qa", split="validation[:100]")
questions = [item['question'] for item in dataset]
choices = [item['choices'] for item in dataset]
answers = [item['answerKey'] for item in dataset]

# %%
few_shot_examples = """Question: What do people typically do when they are tired?
Choices: (A) rest (B) run (C) jump (D) work (E) exercise
Answer: Let me think step by step. When people are tired, they need to recover energy. Resting helps recover energy. Running, jumping, working, and exercising all require energy. The answer is (A) rest.

Question: Where would you find a fish that is not alive?
Choices: (A) ocean (B) aquarium (C) plate (D) river (E) lake
Answer: Let me think step by step. A fish that is not alive would be dead. Dead fish can be cooked and served on a plate. Ocean, aquarium, river, and lake contain live fish. The answer is (C) plate.

"""

# %%
def format_question(question, choices_dict):
    labels = choices_dict['label']
    texts = choices_dict['text']
    choices_str = " ".join([f"({labels[i]}) {texts[i]}" for i in range(len(labels))])
    return f"{question}\nChoices: {choices_str}"

def generate_responses(question, choices_dict, num_samples=5):
    responses = []
    formatted_q = format_question(question, choices_dict)

    for _ in range(num_samples):
        prompt = few_shot_examples + f"Question: {formatted_q}\nAnswer: Let me think step by step."
        inputs = tokenizer(prompt, return_tensors="pt").to(model.device)

        outputs = model.generate(
            **inputs,
            max_new_tokens=150,
            do_sample=True,
            temperature=0.7,
            top_p=0.9,
            pad_token_id=tokenizer.eos_token_id
        )

        response = tokenizer.decode(outputs[0], skip_special_tokens=True)
        response = response.split("Answer:")[-1].strip()
        responses.append(response)

    return responses

# %%
all_responses = []
for i in range(len(questions)):
    print(f"Processing {i+1}/100: {questions[i][:50]}...")
    responses = generate_responses(questions[i], choices[i])
    all_responses.append(responses)
# Out:
# Processing 1/100: A revolving door is convenient for two direction t...
# Processing 2/100: What do people aim to do at work?...
# Processing 3/100: Where would you find magazines along side many oth...
# Processing 4/100: Where are  you likely to find a hamburger?...
# Processing 5/100: James was looking for a good place to buy farmland...
# Processing 6/100: What island country is ferret popular?...
# Processing 7/100: In what Spanish speaking North American country ca...
# Processing 8/100: What do animals do when an enemy is approaching?...
# Processing 9/100: Reading newspaper one of many ways to practice you...
# Processing 10/100: What do people typically do while playing guitar?...
# Processing 11/100: What would vinyl be an odd thing to replace?...
# Processing 12/100: If you want harmony, what is something you should ...
# Processing 13/100: Where does a heifer's master live?...
# Processing 14/100: Aside from water and nourishment what does your do...
# Processing 15/100: Janet was watching the film because she liked what...
# Processing 16/100: What are you waiting alongside with when you're in...
# Processing 17/100: When drinking booze what can you do to stay busy?...
# Processing 18/100: A fencing thrust with a sharp sword towards a pers...
# Processing 19/100: Unlike a spider and his many sight seers, people o...
# Processing 20/100: Where do adults use glue sticks?...
# Processing 21/100: What could go on top of wood?...
# Processing 22/100: The artist was sitting quietly pondering, then sud...
# Processing 23/100: Though the thin film seemed fragile, for it's inte...
# Processing 24/100: Where could you find a toilet that only friends ca...
# Processing 25/100: What is someone who isn't clever, bright, or compe...
# Processing 26/100: When wildlife reproduce we often refer to what com...
# Processing 27/100: The weasel was becoming a problem, it kept getting...
# Processing 28/100: Blue read material outside of his comfort zone bec...
# Processing 29/100: After he got hired he hoped for success at his wha...
# Processing 30/100: Committing perjury is a serious what?...
# Processing 31/100: If you are prone to postpone work what will you ha...
# Processing 32/100: James wanted to find an old underground map from t...
# Processing 33/100: Sean was in a rush to get home, but the light turn...
# Processing 34/100: Where would a person be doing when having to wait ...
# Processing 35/100: She was always helping at the senior center, it br...
# Processing 36/100: The lock kept the steering wheel from moving, but ...
# Processing 37/100: Who is a police officer likely to work for?...
# Processing 38/100: If you have leftover cake, where would you put it?...
# Processing 39/100: A human wants to submerge himself in water, what s...
# Processing 40/100: Where is a doormat likely to be in front of?...
# Processing 41/100: Bob the lizard lives in a warm place with lots of ...
# Processing 42/100: August needed  money because he was afraid that he...
# Processing 43/100: He needed more information to fix it, so he consul...
# Processing 44/100: Where can you put a picture frame when it's not hu...
# Processing 45/100: James knew that he shouldn't have been buying beer...
# Processing 46/100: What is the result of applying for  job?...
# Processing 47/100: What must someone do before they shop?...
# Processing 48/100: Because John was first violin, he had to bring som...
# Processing 49/100: What is a place that usually does not have an elev...
# Processing 50/100: Who is likely to be excited about a crab?...
# Processing 51/100: Where can a human find clothes that aren't pants?...
# Processing 52/100: If I was getting drunk, and people couldn't unders...
# Processing 53/100: When a person is beginning work, what are they bui...
# Processing 54/100: A child wants to play, what would they likely want...
# Processing 55/100: Talking to the same person about the same thing ov...
# Processing 56/100: The teacher doesn't tolerate noise during a test i...
# Processing 57/100: The freeway had no traffic and few buildings, wher...
# Processing 58/100: Where would you go if you wanted to have fun with ...
# Processing 59/100: If there is a place that is hot and arid, what cou...
# Processing 60/100: What is likely to satisfy someone's curiosity?...
# Processing 61/100: If you are in a bar in a glove shaped state where ...
# Processing 62/100: Where would a computer user be using their own com...
# Processing 63/100: Crabs live in what sort of environment?...
# Processing 64/100: Where can you find a snake in tall grass?...
# Processing 65/100: What is a place that has a bench nestled in trees?...
# Processing 66/100: Where is a human likely to go as a result of being...
# Processing 67/100: He was beginning to regret taking the fight when h...
# Processing 68/100: Where would you find a single shower curtain being...
# Processing 69/100: Where is a good idea but not required to have a fi...
# Processing 70/100: What continent has the most castles?...
# Processing 71/100: If you have to read a book that is very dry and lo...
# Processing 72/100: Sally used a clipboard to hold her papers while sh...
# Processing 73/100: The kids didn't clean up after they had done what?...
# Processing 74/100: Despite the name a pawn can be quite versatile, al...
# Processing 75/100: What would not be true about a basketball if it ha...
# Processing 76/100: If you are awaking multiple times throughout the n...
# Processing 77/100: Where does a wild bird usually live?...
# Processing 78/100: Where would you expect to find white mice?...
# Processing 79/100: John felt that his actions were fate.   Harry said...
# Processing 80/100: What could committing murder prevent someone from ...
# Processing 81/100: George didn't have a car, but he still had his two...
# Processing 82/100: A crane uses many a steel cable when working a wha...
# Processing 83/100: What is the main purpose of farmers?...
# Processing 84/100: Where can I put this penny to save for later?...
# Processing 85/100: Where would you put uncooked crab meat?...
# Processing 86/100: The man had a fear of illness, so he never visited...
# Processing 87/100: Where would you put pans if you want to bring them...
# Processing 88/100: If you're remembering something, it's because of y...
# Processing 89/100: Which large land mass is home to the most monkeys?...
# Processing 90/100: Friday was James's 5th Anniversary.  They planned ...
# Processing 91/100: The teens were trying to hide that they get drink,...
# Processing 92/100: You'll find a landing at the top of what?...
# Processing 93/100: Anybody could be hired in the kitchen, what was ne...
# Processing 94/100: Where can you find a number of wind instruments to...
# Processing 95/100: A mountie got off at a subway stop.  What city mig...
# Processing 96/100: What do you want someone to do when you illustrate...
# Processing 97/100: Billy set aside a block of time for having fun aft...
# Processing 98/100: The man in the white suit was very lazy.  He did n...
# Processing 99/100: What would you be unable to do if you have too muc...
# Processing 100/100: It was a long trip from the farm, so he stayed in ...

# %%
embedding_model = SentenceTransformer('all-MiniLM-L6-v2')

def semantic_entropy(responses):
    if len(responses) < 2:
        return 0.0

    embeddings = embedding_model.encode(responses)
    clustering = DBSCAN(eps=0.5, min_samples=1, metric='cosine').fit(embeddings)
    labels = clustering.labels_

    cluster_counts = Counter(labels)
    total = len(labels)
    probs = [count / total for count in cluster_counts.values()]

    entropy = -sum(p * np.log(p) for p in probs if p > 0)
    return entropy

def self_consistency(responses):
    if len(responses) < 2:
        return 1.0

    normalized = [r.strip().lower()[:50] for r in responses]
    most_common = Counter(normalized).most_common(1)[0][1]
    consistency = most_common / len(responses)

    return 1 - consistency

def token_entropy_approx(responses):
    all_tokens = []
    for response in responses:
        tokens = response.lower().split()
        all_tokens.extend(tokens)

    if len(all_tokens) == 0:
        return 0.0

    token_counts = Counter(all_tokens)
    total = len(all_tokens)
    probs = [count / total for count in token_counts.values()]

    entropy = -sum(p * np.log(p) for p in probs if p > 0)
    return entropy

def perplexity_approx(responses):
    token_ent = token_entropy_approx(responses)
    return np.exp(token_ent)

def lexical_diversity(responses):
    combined_text = " ".join(responses)

    if len(combined_text.strip()) == 0:
        return 0.0

    lex = LexicalRichness(combined_text)
    try:
        ttr = lex.ttr
    except:
        ttr = 0.0

    return ttr
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
results = []

for i, responses in enumerate(all_responses):
    se = semantic_entropy(responses)
    sc = self_consistency(responses)
    te = token_entropy_approx(responses)
    ppl = perplexity_approx(responses)
    ld = lexical_diversity(responses)

    results.append({
        'question': questions[i],
        'semantic_entropy': se,
        'self_consistency': sc,
        'token_entropy': te,
        'perplexity': ppl,
        'lexical_diversity': ld
    })

df = pd.DataFrame(results)

# %%
import re

def extract_answer_letter(response):
    patterns = [
        r'\(([A-E])\)',
        r'answer is \(?([A-E])\)?',
        r'answer: \(?([A-E])\)?',
        r'^([A-E])\b'
    ]

    for pattern in patterns:
        match = re.search(pattern, response, re.IGNORECASE)
        if match:
            return match.group(1).upper()

    return None

def check_correctness(response, ground_truth):
    pred_letter = extract_answer_letter(response)

    if pred_letter is None:
        return False

    return pred_letter == ground_truth.upper()

correctness = []
for i, responses in enumerate(all_responses):
    correct = any(check_correctness(r, answers[i]) for r in responses)
    correctness.append(correct)

df['correct'] = correctness
print(f"Accuracy: {sum(correctness)/len(correctness):.2%}")
# Out:
# Accuracy: 32.00%

# %%
def calculate_ece(predictions, correctness, n_bins=10):
    df_temp = pd.DataFrame({
        'pred': predictions,
        'correct': correctness
    })

    df_temp['bin'] = pd.cut(df_temp['pred'], bins=n_bins, labels=False, duplicates='drop')

    ece = 0.0
    for bin_idx in df_temp['bin'].unique():
        if pd.isna(bin_idx):
            continue

        bin_data = df_temp[df_temp['bin'] == bin_idx]

        if len(bin_data) == 0:
            continue

        avg_confidence = bin_data['pred'].mean()
        avg_accuracy = bin_data['correct'].mean()
        bin_weight = len(bin_data) / len(df_temp)

        ece += bin_weight * abs(avg_confidence - avg_accuracy)

    return ece

metric_names = ['semantic_entropy', 'self_consistency', 'token_entropy', 'perplexity', 'lexical_diversity']

print("\nCommonsenseQA (Reasoning Category) ECE Results:")
for metric in metric_names:
    normalized = (df[metric] - df[metric].min()) / (df[metric].max() - df[metric].min() + 1e-8)
    ece = calculate_ece(normalized, df['correct'])
    print(f"{metric}: ECE = {ece:.4f}")
# Out:
# CommonsenseQA (Reasoning Category) ECE Results:
# semantic_entropy: ECE = 0.6127
# self_consistency: ECE = 0.6900
# token_entropy: ECE = 0.4141
# perplexity: ECE = 0.2502
# lexical_diversity: ECE = 0.4681

# %%
df.to_csv('commonsenseqa_results.csv', index=False)
